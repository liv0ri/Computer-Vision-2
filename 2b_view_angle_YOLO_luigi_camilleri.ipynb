# %% [markdown]
# # Task 2b: Sign Detection with YOLOv11
#
# **Student:** Luigi Camilleri
# **Student ID:** 0312805L
# **Model:** YOLOv11
#
#
# This notebook implements a YOLOv11 object detector to detect Maltese traffic signs. It covers:
# 1.  **Dataset Preparation**: Setting up the data.yaml configuration and specifying its path
# 2.  **Model Training**: Fine-tuning a pre-trained `YOLOv11` model.
# 3.  **Evaluation**: Evaluating the best-performing YOLOv11 model on the test set.
# 4.  **Inference & Analytics**: Visualising evaluation curves and comparing ground-truth labels with model predictions.

# %%
import importlib
import subprocess
import sys
import os
import glob
import matplotlib.pyplot as plt

# Enable inline plotting for Jupyter notebooks
# %matplotlib inline


#  Package bootstrap helper
def ensure_package(pkg: str, import_name: str | None = None, pip_name: str | None = None):
    try:
        return importlib.import_module(import_name or pkg)
    except ImportError:
        pip_target = pip_name or pkg
        print(f"Installing missing package: {pip_target}")
        subprocess.check_call(
            [sys.executable, "-m", "pip", "install", pip_target],
            stdout=subprocess.DEVNULL
        )
        return importlib.import_module(import_name or pkg)

# Ensures third-party packages
torch = ensure_package("torch")
ultralytics = ensure_package("ultralytics")

#  Used for reproducibility in torch operations
torch.manual_seed(42)

print("Environment ready: all dependencies installed and imported.")
# Out:
# Environment ready: all dependencies installed and imported.

# %% [markdown]
# ## 1. Dataset Preparation
#
# The dataset for the YOLOv11 model is prepared automatically by the data.yaml file in the YOLO_COCO dataset

# %%
# Path to the data.yaml file
DATA_YAML = 'Assignment Material/YOLO_COCO_view_angle/data.yaml'

# %% [markdown]
# ## 2. Model Training

# %%
from ultralytics import YOLO

# Loads a pre-trained YOLOv11 model
model = YOLO('yolo11m.pt')
# Trains the model and gets the training results
results = model.train(
    data=DATA_YAML,
    epochs=100,
    imgsz=640,
    batch=8,
    project='models',
    name='yolov11_view_angle',
    exist_ok=True
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 100% ━━━━━━━━━━━━ 38.8MB 311.2MB/s 0.1s
# Ultralytics 8.4.3 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Assignment Material/YOLO_COCO_view_angle/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolov11_view_angle, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=models, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/models/yolov11_view_angle, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 25.0MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1413337  ultralytics.nn.modules.head.Detect           [3, 16, None, [256, 512, 512]]
# YOLO11m summary: 232 layers, 20,055,321 parameters, 20,055,305 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 121.7MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3829.3±755.2 MB/s, size: 1576.1 KB)
# train: Scanning /content/Assignment Material/YOLO_COCO_view_angle/labels/train... 495 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 495/495 1.9Kit/s 0.3s
# train: New cache created: /content/Assignment Material/YOLO_COCO_view_angle/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1491.2±1551.8 MB/s, size: 1278.5 KB)
# val: Scanning /content/Assignment Material/YOLO_COCO_view_angle/labels/val... 99 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 99/99 1.4Kit/s 0.1s
# val: New cache created: /content/Assignment Material/YOLO_COCO_view_angle/labels/val.cache
# Plotting labels to /content/models/yolov11_view_angle/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001429, momentum=0.9) with parameter groups 0 weight(decay=0.0), 0 weight(decay=0.0005), 12 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content
2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.1s
#                    all         99        112      0.883       0.83      0.903      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      5.84G     0.4538      0.308       0.89         14        640: 100% ━━━━━━━━━━━━ 62/62 1.6it/s 38.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.0it/s 2.3s
#                    all         99        112       0.83      0.858      0.898      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100       5.9G     0.4527     0.3086      0.889         10        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 43.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.3it/s 2.1s
#                    all         99        112      0.854      0.838      0.887      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      5.97G     0.4648     0.3172     0.8904         19        640: 100% ━━━━━━━━━━━━ 62/62 1.5it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.0s
#                    all         99        112      0.858      0.845      0.892      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      6.04G     0.4411     0.2963     0.8914         15        640: 100% ━━━━━━━━━━━━ 62/62 1.5it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all         99        112       0.85      0.882      0.902      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100       6.1G     0.4379     0.3001     0.8923         16        640: 100% ━━━━━━━━━━━━ 62/62 1.3it/s 46.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.9it/s 2.5s
#                    all         99        112      0.909      0.822      0.902      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      6.17G     0.4514     0.3032     0.8847         22        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 43.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.0it/s 1.8s
#                    all         99        112       0.89       0.83      0.901      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      6.23G     0.4626     0.3188     0.8913         13        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 43.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.2it/s 1.7s
#                    all         99        112      0.896      0.824        0.9      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100       6.3G     0.4249      0.302     0.8785         13        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 44.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.3it/s 2.1s
#                    all         99        112      0.894      0.813      0.896      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      6.37G     0.4303     0.3002     0.8778         24        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 43.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 2.0s
#                    all         99        112      0.882      0.829       0.87      0.708
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      6.43G     0.4167     0.2885     0.8767         15        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 43.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.7it/s 1.9s
#                    all         99        112      0.892      0.826      0.882      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100       6.5G     0.4077     0.2846     0.8791         11        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 44.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 1.9s
#                    all         99        112      0.898       0.81      0.884       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      6.56G     0.4215     0.2898     0.8732         18        640: 100% ━━━━━━━━━━━━ 62/62 1.5it/s 42.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.9it/s 2.4s
#                    all         99        112      0.903      0.809      0.891      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      6.63G     0.4287     0.3013      0.885         12        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 43.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 2.0s
#                    all         99        112      0.882      0.819      0.887      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100       6.7G     0.4112     0.2776     0.8838         13        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.0s
#                    all         99        112      0.886      0.819       0.89      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      6.76G      0.425     0.2892     0.8756         15        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 44.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.3it/s 2.1s
#                    all         99        112      0.892      0.815      0.884       0.71
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      6.88G     0.3885     0.2721     0.8691         19        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all         99        112      0.895      0.816      0.891      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100         7G     0.3908     0.2684     0.8657         18        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 43.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.5it/s 2.0s
#                    all         99        112       0.89       0.83      0.892      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100       7.1G     0.4102     0.2785     0.8676         17        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 43.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.1s
#                    all         99        112      0.877      0.843       0.89      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      7.22G     0.3988     0.2746     0.8667         16        640: 100% ━━━━━━━━━━━━ 62/62 1.5it/s 42.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all         99        112      0.893      0.823      0.888       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      7.34G     0.3878     0.2589     0.8736         15        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.0s
#                    all         99        112      0.881      0.834      0.888      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      7.44G     0.3778     0.2619     0.8757          9        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 44.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.9it/s 1.8s
#                    all         99        112      0.886      0.819      0.894      0.724
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.95G     0.3555     0.2313     0.8106          7        640: 100% ━━━━━━━━━━━━ 62/62 1.3it/s 49.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all         99        112      0.889      0.804      0.886      0.708
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      4.95G     0.3368     0.2224     0.8239          9        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.8it/s 1.8s
#                    all         99        112       0.88      0.805      0.883      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.95G     0.3314     0.2245     0.8138          7        640: 100% ━━━━━━━━━━━━ 62/62 1.5it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 2.0s
#                    all         99        112      0.895      0.814      0.889      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.95G     0.3317     0.2166     0.8047          8        640: 100% ━━━━━━━━━━━━ 62/62 1.5it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.1s
#                    all         99        112      0.805      0.874      0.886      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.95G     0.3297     0.2198     0.8109          7        640: 100% ━━━━━━━━━━━━ 62/62 1.5it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.7it/s 1.9s
#                    all         99        112      0.879      0.815      0.894       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.99G     0.3225     0.2111     0.7966          7        640: 100% ━━━━━━━━━━━━ 62/62 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.0it/s 1.7s
#                    all         99        112      0.868      0.821      0.877      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      5.04G      0.325       0.21     0.8019          7        640: 100% ━━━━━━━━━━━━ 62/62 1.5it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.5it/s 2.0s
#                    all         99        112      0.871      0.835      0.894      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      5.08G     0.3097     0.2003     0.8014          8        640: 100% ━━━━━━━━━━━━ 62/62 1.5it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.0s
#                    all         99        112      0.869      0.835      0.894      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      5.13G     0.3198     0.2109     0.8136          9        640: 100% ━━━━━━━━━━━━ 62/62 1.7it/s 37.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.1s
#                    all         99        112      0.884      0.813      0.894      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      5.21G     0.3138     0.2048     0.8012          8        640: 100% ━━━━━━━━━━━━ 62/62 1.4it/s 44.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.4it/s 2.0s
#                    all         99        112       0.86      0.839      0.897      0.727
#
# 100 epochs completed in 1.336 hours.
# Optimizer stripped from /content/models/yolov11_view_angle/weights/last.pt, 40.5MB
# Optimizer stripped from /content/models/yolov11_view_angle/weights/best.pt, 40.5MB
#
# Validating /content/models/yolov11_view_angle/weights/best.pt...
# Ultralytics 8.4.3 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 126 layers, 20,032,345 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all         99        112      0.883      0.829      0.904      0.733
#                   Back         40         42      0.923      0.862      0.909      0.784
#                  Front         25         28      0.855      0.821       0.96      0.862
#                   Side         39         42      0.871      0.805      0.843      0.554
# Speed: 0.5ms preprocess, 10.5ms inference, 0.0ms loss, 4.8ms postprocess per image
# Results saved to /content/models/yolov11_view_angle

# %% [markdown]
# ## 3. Evaluating on Test Set

# %% [markdown]
# This section loads the best fine tuned YOLOv11 model and evaluates its performance on the test set, generating metrics and plots to assess detection accuracy.

# %%
# Evaluates the best trained model on the test set and generate plots
best_model = YOLO('models/yolov11_view_angle/weights/best.pt')
test_results = best_model.val(
    data=DATA_YAML,
    project="runs", # The parent directory name
    name="yolov11_view_angle",
    split="test",    # explicitly uses the test set
    plots=True       # generates plots like confusion matrix, PR curves
)
# Out:
# Ultralytics 8.4.3 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 126 layers, 20,032,345 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2844.3±395.0 MB/s, size: 2480.0 KB)
# val: Scanning /content/Assignment Material/YOLO_COCO_view_angle/labels/test.cache... 116 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 116/116 34.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.2s/it 9.6s
#                    all        116        130      0.876      0.839      0.872      0.724
#                   Back         46         49      0.862      0.918      0.925       0.83
#                  Front         33         36       0.88      0.889        0.9      0.805
#                   Side         43         45      0.885      0.711      0.793      0.536
# Speed: 2.9ms preprocess, 18.9ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to /content/runs/yolo11_view_angle

# %% [markdown]
# ## 4. Analytics & Visualization

# %% [markdown]
# This section provides functions and tools to visualize the results and analytics of the YOLOv11 model, including displaying images and evaluation plots.

# %%
# Directory containing YOLOv11's best model's outputs
val_dir = 'runs/yolov11_view_angle'

# Function which displays images from a folder in a grid format
def show_images_from_folder(
    folder,
    title,
    patterns,
    cols = 2,
    img_size=5
):

    image_paths = []
    for pattern in patterns:
        image_paths.extend(glob.glob(os.path.join(folder, pattern)))
    image_paths.sort()

    if not image_paths:
        print(f'No images found in {folder}')
        return

    n = len(image_paths)
    rows = (n + cols - 1) // cols # Logic used to get number of rows needed

    # Figure size scaling with rows
    fig_width = cols * img_size
    fig_height = rows * img_size

    # Creates subplots
    fig, axes = plt.subplots(
        rows, cols,
        figsize=(fig_width, fig_height),
        constrained_layout=True
    )

    # Flattens axes array for easy iteration
    axes = axes.flatten()

    for ax, img_path in zip(axes, image_paths):
        img = plt.imread(img_path)
        ax.imshow(img)
        ax.set_aspect('equal')
        ax.axis('off')

    fig.suptitle(title, fontsize=16)
    plt.show()
    plt.close(fig)

# %% [markdown]
# ### Evaluation Plots

# %% [markdown]
# Displays key evaluation plots such as the confusion matrix, precision-recall curves and F1-curves to help interpret the model's performance.

# %%
plot_patterns = (
    'confusion_matrix*.png',
    '*curve*.png',
)

show_images_from_folder(
    val_dir,
    title='YOLOv11 Evaluation Plots',
    patterns=plot_patterns
)

# %% [markdown]
# ### Labels and Predictions

# %% [markdown]
# Shows sample images with predicted bounding boxes and labels, allowing for a visual comparison between model predictions and ground truth.

# %%
val_batch_patterns = ('val_batch*.jpg', 'val_batch*.png')

show_images_from_folder(
    val_dir,
    title='YOLOv11 Validation Batch Predictions',
    patterns=val_batch_patterns
)
